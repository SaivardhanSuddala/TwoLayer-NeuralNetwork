# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mlt
import math as Math

# %%
class Value:
    def __init__(self,data,_children=(),op='',label=''):
        self.data=data
        self.back=set(_children)
        self.op=op
        self.grad=0
        self.label=label
    def __repr__(self):
        return f"value ({self.data})"
    def __add__(self,other):
        out =Value((self.data+other.data),(self,other))
        return out
    def __mul__(self,other):
        out =Value((self.data*other.data),(self,other))
        return out

    def tanh(self):
        out=Value(((Math.exp(2*self.data))-1)/(Math.exp(2*self.data)+1))
        return out
a=Value(3)
b=Value(4)
c=a*b
c.back
# Out:
# {value (3), value (4)}

# %%
def undBackProp():
    a=Value(2,label='a')
    b=Value(5,label='b')
    c=Value(-0.5,label='c')
    f=Value(0.7,label='f')
    e=a*b
    d=c+e
    l=d*f
    print(l)

    a=Value(2,label='a')
    b=Value(5,label='b')
    c=Value(-0.5,label='c')
    f=Value(0.7,label='f')
    e=a*b
    d=c+e
    l=d*f
    print(l)
undBackProp()
# Out:
# value (6.6499999999999995)
# value (6.6499999999999995)

# %%
#Actual Neuron which have weights and biases
x1=Value(-3,label='x1')
x2=Value(0,label='x2')

w1=Value(-3,label='w1')
w2=Value(1,label='w1')

b=Value(6.8813735870195432,label='b')

x1w1=x1*w1
x2w2=x2*w2
n1=x1w1+x2w2
n=x1w1+x2w2+b
o=n.tanh()
print(o)
# Out:
# value (0.9999999999999679)

# %%
#Backpropping and giving grads manually
o.grad=1
print(o.grad)
n.grad=1-(o.data**2)
print(n.grad)
# Out:
# 1
# 6.417089082333405e-14
